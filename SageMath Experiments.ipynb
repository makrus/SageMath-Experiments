# %%
l8 = [3*x%8 for x in range(1,108)]
pl8 = list_plot(l8, color='blue', pointsize=30)

l12 = [8*x%12 for x in range(1,108)]
pl12 = list_plot(l12, color='red', pointsize=30)

l7 = [9*x%7 for x in range(1,108)]
pl7 = list_plot(l7, color='yellow', pointsize=30)

l9 = [4*x%9 for x in range(1,108)]
pl9 = list_plot(l9, color='green', pointsize=30)

l27 = [8*x%27 for x in range(1,108)]
pl27 = list_plot(l27, color='orange', pointsize=30)

l10 = [9*x%10 for x in range(1,108)]
pl10 = list_plot(l10, color='brown', pointsize=30)

show(pl8+pl12+pl7+pl9+pl10+pl27, figsize=[18,4])
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
@interact
def plt(n=5, f=[sin, cos, tan]):
    return plot(f(n*x))
# Out:
# Interactive function <function plt at 0x7f785c9ab9e0> with 2 widgets
#   n: IntSlider(value=5, description='n', …
